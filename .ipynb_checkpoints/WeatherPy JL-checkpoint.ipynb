# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
pip install citipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "Instructions/output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 632

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = f"{url}appid={weather_api_key}&units=imperial&q="
response = requests.get(query_url + "atlanta").json()
pprint(response)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 33.749, 'lon': -84.388},
#  'dt': 1634834477,
#  'id': 4180439,
#  'main': {'feels_like': 69.71,
#           'humidity': 79,
#           'pressure': 1021,
#           'temp': 69.37,
#           'temp_max': 73.24,
#           'temp_min': 64.92},
#  'name': 'Atlanta',
#  'sys': {'country': 'US',
#          'id': 2041852,
#          'sunrise': 1634816838,
#          'sunset': 1634856998,
#          'type': 2},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 230, 'gust': 4, 'speed': 1.01}}

# %%
url2 = "http://api.openweathermap.org/data/2.5/weather?"
query_url2 = f"{url2}appid={weather_api_key}&units=imperial&q="

# set up lists to hold response info
max_temp = []
humidity = []
clouds = []
wind_speed = []
country = []
date = []
found_city = []
latitude = []
longitude = []

print('Beginning Data Retrieval')
print('---------------------------------')

# loop through list of cities and perform request for data on each
for i in range(len(cities)):
    city = cities[i]
        
    # create search query, make request, and store in json
    weather_response = requests.get(query_url2 + city).json()
    
    # handle exceptions for a city that is not available/found
    try:
        # grab required information
        max_temp.append(weather_response['main']['temp_max'])
        humidity.append(weather_response['main']['humidity'])
        clouds.append(weather_response['clouds']['all'])
        wind_speed.append(weather_response['wind']['speed'])
        country.append(weather_response['sys']['country'])
        date.append(weather_response['dt'])
        found_city.append(city)
        latitude.append(weather_response['coord']['lat'])
        longitude.append(weather_response['coord']['lon'])
        print(f'Processing Record {i+1} of {len(cities)} | {city}')
                
    except:
        print('City not found. Skipping...')
# Out:
# Beginning Data Retrieval
# ---------------------------------
# Processing Record 1 of 632 | albany
# City not found. Skipping...
# Processing Record 3 of 632 | coolum beach
# Processing Record 4 of 632 | busselton
# Processing Record 5 of 632 | sistranda
# Processing Record 6 of 632 | hudson bay
# City not found. Skipping...
# Processing Record 8 of 632 | hauterive
# Processing Record 9 of 632 | rikitea
# Processing Record 10 of 632 | jamestown
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 13 of 632 | hilo
# Processing Record 14 of 632 | hithadhoo
# Processing Record 15 of 632 | ribeira grande
# Processing Record 16 of 632 | hobart
# Processing Record 17 of 632 | mufumbwe
# Processing Record 18 of 632 | abilene
# City not found. Skipping...
# Processing Record 20 of 632 | bluff
# Processing Record 21 of 632 | clonakilty
# Processing Record 22 of 632 | khatanga
# Processing Record 23 of 632 | itacoatiara
# Processing Record 24 of 632 | qaanaaq
# ...

# %%
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | yerbogachen
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | touba
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | rio grande
# Processing Record 7 of Set 1 | ibra
# Processing Record 8 of Set 1 | port elizabeth
# Processing Record 9 of Set 1 | tuktoyaktuk
# Processing Record 10 of Set 1 | avarua
# Processing Record 11 of Set 1 | nemuro
# Processing Record 12 of Set 1 | morgan city
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | kawalu
# Processing Record 15 of Set 1 | hami
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | katsuura
# Processing Record 18 of Set 1 | hjallerup
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | bengkulu
# Processing Record 21 of Set 1 | victoria
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weatherDF = pd.DataFrame(
    {
        "City": found_city,
        "Lat": latitude,
        "Lng": longitude,
        "Max Temp": max_temp,
        "Humidity": humidity,
        "Cloudiness": clouds,
        "Wind Speed": wind_speed,
        "Country": country,
        "Date": date
    }
)

weatherDF.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        albany  42.6001  -73.9662     73.54        62          60
# 1  coolum beach -26.5333  153.1000     70.11        96          40
# 2     busselton -33.6500  115.3333     51.08        86          44
# 3     sistranda  63.7256    8.8340     46.90        84         100
# 4    hudson bay  52.8500 -102.3842     35.22        51           4
#
#    Wind Speed Country        Date
# 0        1.01      US  1634835992
# 1        4.63      AU  1634836125
# 2        6.06      AU  1634836016
# 3       43.44      NO  1634836126
# 4        5.30      CA  1634836126

# %%
# export city data into a csv file
weatherDF.to_csv(output_data_file)

# %%
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %%
# summary stats table
weatherDF[["Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Date"]].describe()
# Out:
#               Lat         Lng    Max Temp   Humidity  Cloudiness  Wind Speed  \
# count  579.000000  579.000000  579.000000  579.00000  579.000000  579.000000
# mean    19.698614   20.075065   62.502383   70.61658   57.792746    7.792660
# std     33.095848   93.130546   20.659840   19.62798   37.337401    6.121406
# min    -54.800000 -179.166700  -16.290000   12.00000    0.000000    0.000000
# 25%     -8.438850  -61.198050   47.760000   61.00000   20.000000    3.440000
# 50%     22.890900   25.850000   68.950000   75.00000   72.000000    6.310000
# 75%     47.560250  107.057300   78.260000   85.50000   94.500000   10.360000
# max     78.218600  178.416700   98.560000  100.00000  100.000000   43.440000
#
#                Date
# count  5.790000e+02
# mean   1.634835e+09
# std    9.394941e+01
# min    1.634834e+09
# 25%    1.634835e+09
# 50%    1.634835e+09
# 75%    1.634835e+09
# max    1.634835e+09

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  599.000000  599.000000  599.000000  599.000000  599.000000  599.000000
# mean    19.877028   19.568998   69.794808   69.353923   51.569282    7.979416
# std     33.262944   91.418472   15.678452   22.704698   35.405602    5.660694
# min    -54.800000 -179.170000   12.200000    7.000000    0.000000    0.360000
# 25%     -8.540000  -61.210000   59.000000   55.000000   20.000000    3.620000
# 50%     24.370000   24.670000   73.110000   75.000000   59.000000    6.730000
# 75%     46.585000  102.255000   80.600000   87.000000   85.000000   11.050000
# max     78.220000  179.320000  116.600000  100.000000  100.000000   42.500000
#
#                Date
# count  5.990000e+02
# mean   1.593605e+09
# std    5.738815e+01
# min    1.593605e+09
# 25%    1.593605e+09
# 50%    1.593605e+09
# 75%    1.593605e+09
# max    1.593605e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weatherDF.shape
# Out:
# (579, 9)

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  550.000000  550.000000  550.000000  550.000000  550.000000  550.000000
# mean    19.973545   17.124400   58.331400   67.890909   52.141818    8.544800
# std     33.284840   91.595451   25.795297   20.864881   35.766469    6.078869
# min    -54.800000 -179.170000  -11.340000    9.000000    0.000000    0.160000
# 25%     -8.077500  -64.627500   42.800000   55.000000   20.000000    4.525000
# 50%     23.630000   19.635000   64.940000   72.000000   57.000000    7.325000
# 75%     48.672500   97.350000   78.800000   83.000000   86.750000   11.410000
# max     78.220000  179.320000  102.200000  100.000000  100.000000   46.080000
#
#                Date
# count  5.500000e+02
# mean   1.585764e+09
# std    5.539674e+01
# min    1.585764e+09
# 25%    1.585764e+09
# 50%    1.585764e+09
# 75%    1.585764e+09
# max    1.585764e+09

# %%
# check for indices of cities with humidity over 100%
highHum = weatherDF.index[weatherDF['Humidity']>100]
highHum
# Out:
# Int64Index([], dtype='int64')

# %%
#  Get the indices of cities that have humidity over 100%.
# Out:
# Int64Index([], dtype='int64')

# %%
# new DF with dropped humidity
clean_city_data = weatherDF.loc[weatherDF["Humidity"] <= 100]

# %%
clean_city_data.shape
# Out:
# (579, 9)

# %%
clean_city_data.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        albany  42.6001  -73.9662     72.81        63          60
# 1  coolum beach -26.5333  153.1000     70.11        96          40
# 2     busselton -33.6500  115.3333     52.09        86          44
# 3     sistranda  63.7256    8.8340     46.90        84         100
# 4    hudson bay  52.8500 -102.3842     35.22        51           4
#
#    Wind Speed Country        Date
# 0        1.99      US  1634834249
# 1        4.63      AU  1634834497
# 2        6.06      AU  1634834492
# 3       43.44      NO  1634834498
# 4        5.30      CA  1634834498

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create a scatter plot for latitude vs. temperature
x_values = clean_city_data['Lat']
y_values = clean_city_data['Max Temp']
plt.scatter(x_values, y_values, marker='o', facecolors='steelblue', edgecolors='black')

# create labels for chart
plt.title('City Latitude vs. Max Temperature (10/21/21)')
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')

# show grid
plt.grid()

# save image of chart
plt.savefig('Instructions/output_data/Fig1.png')
plt.show()

# %% [markdown]
# This plot is analyzing the relationship between the cities' latitude and max temperature. In this instance we can infer that the closer to the equator (latitude of 0) we get, the higher the max temperatures.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create a scatter plot for latitude vs. humidity
x_values = clean_city_data['Lat']
y_values = clean_city_data['Humidity']
plt.scatter(x_values, y_values, marker='o', facecolors='steelblue', edgecolors='black')

# create labels for chart
plt.title('City Latitude vs. Humidity (10/21/21)')
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')

# show grid
plt.grid()

# save image of chart
plt.savefig('Instructions/output_data/Fig2.png')
plt.show()

# %% [markdown]
# This plot is analyzing the relationship between the cities' latitude and humidities. Based on this chart, we can see that latitude does not affect humidity rates. Humidity is a wide range across all latitude points.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create a scatter plot for latitude vs. cloudiness
x_values = clean_city_data['Lat']
y_values = clean_city_data['Cloudiness']
plt.scatter(x_values, y_values, marker='o', facecolors='steelblue', edgecolors='black')

# create labels for chart
plt.title('City Latitude vs. Cloudiness (10/21/21)')
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')

# show grid
plt.grid()

# save image of chart
plt.savefig('Instructions/output_data/Fig3.png')
plt.show()

# %% [markdown]
# This plot is analyzing the relationship between the cities' latitude and cloudiness. Much like latitude vs. humidity, latitude does not affect cloudiness. Cloudiness is a wide range across all latitude points.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create a scatter plot for latitude vs. wind speed
x_values = clean_city_data['Lat']
y_values = clean_city_data['Wind Speed']
plt.scatter(x_values, y_values, marker='o', facecolors='steelblue', edgecolors='black')

# create labels for chart
plt.title('City Latitude vs. Wind Speed (10/21/21)')
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')

# show grid
plt.grid()

# save image of chart
plt.savefig('Instructions/output_data/Fig4.png')
plt.show()

# %% [markdown]
# This plot is analyzing the relationship between the cities' latitude and wind speed. In this instance we can infer that the furthest from the equator (latitude of 0) we get, we see some of the highest wind speeds, especially in the Northern hemisphere.

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# create DF only using Northern hemisphere data
northHem = clean_city_data.loc[clean_city_data["Lat"] > 0]

# %%
# Add the linear regression equation
x_values = northHem['Lat']
y_values = northHem['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

# Add line to plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values, y_values)

# Plot regression line
plt.plot(x_values, regress_values, "r--")
plt.annotate(line_eq, (2,2), fontsize=15, color='r')

# Label plot
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression (10/21/21)')
plt.xlabel('Latitude')
plt.ylabel('Max Temp')

# Print r squared value
print(f'The r-value is: {rvalue**2}')

# Show plot
plt.show()
# Out:
# The r-value is: 0.7648666314557482

# %% [markdown]
# This chart shows the linear regression between the northern hemisphere's latitude versus its max temperatures. As you can see from the chart, the higher north you go, the lower the max temperatures are. The r-value is 0.76 which proves there is a strong correlation between latitude and max temperatures in the northern hemisphere.

# %%
# Out:
# The r-value is: 0.46937863826630627

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.6082708688906918

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.017128274759839232
